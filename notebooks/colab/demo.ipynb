# %% [markdown]
# # Nheengatu Constitution Corpus
# ## Demo dos 5.028 pares de sentenças

# %%
import json
import pandas as pd

with open('data/processed/merged_5028_pairs.json', 'r') as f:
    data = json.load(f)

df = pd.DataFrame(data)
print(f"Total: {len(df)} pares")
df.head()
